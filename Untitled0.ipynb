# %% [markdown]
# <a href="https://colab.research.google.com/github/vitormenezes-star/Atividade_Cesta_Basica/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
*import pandas as pd

# Criar um DataFrame com dados fictícios
data = {
    'Produto': ['Arroz', 'Feijão', 'Óleo de soja', 'Açúcar', 'Leite'],
    'Preço Anterior': [20.00, 8.00, 6.00, 4.50, 3.50],
    'Preço Atual': [22.50, 8.00, 5.80, 4.80, 3.70]
}

df = pd.DataFrame(data)

# Calcular variação percentual
df['Variação (%)'] = ((df['Preço Atual'] - df['Preço Anterior']) / df['Preço Anterior']) * 100

# Exibir a tabela com as variações
df
# Out:
#         Produto  Preço Anterior  Preço Atual  Variação (%)
# 0         Arroz            20.0         22.5     12.500000
# 1        Feijão             8.0          8.0      0.000000
# 2  Óleo de soja             6.0          5.8     -3.333333
# 3        Açúcar             4.5          4.8      6.666667
# 4         Leite             3.5          3.7      5.714286
